# %%
import os 
from copy import deepcopy 
import numpy as np 
import pandas as pd

import seaborn
import matplotlib.colors as mcolors
import matplotlib.pyplot as plt
# %matplotlib inline 

import matplotlib.gridspec as gridspec

# %%
os.chdir('/home/zhouc1/notebooks/definexpfam_results/geyser_waiting')

# %%
fig = plt.figure(constrained_layout=False)

plot_pts_cnt = 4000
xlimit = (21., 124.)
ylimit = (-0.005, 0.0701)

x0 = np.linspace(xlimit[0], xlimit[1], plot_pts_cnt).reshape(-1, 1)

basisfunction_name = 'Gaussian'
var_name = 'waiting'
fig.set_figheight(30) # 40 
fig.set_figwidth(80) # 65
ncols = 8
nrows = 3
fontsize_label = 40
fontsize_info = 40
fontsize_tick = 25
linewidth = 2.0

bw_list = [6.0, 8.0, 10.0]

widths = [1, 1, 1, 1, 1]
heights = [1, 1, 1, 1]
spec = fig.add_gridspec(ncols = ncols, 
                        nrows = nrows, 
                        width_ratios = widths,
                        height_ratios = heights)

# spec = gridspec.GridSpec(ncols=ncols, nrows=nrows, figure=fig)

# # ---------------------------------------------------------------------------------------------
# ax = fig.add_subplot(spec[0, 0])
# ax.text(0.5 * (xlimit[0] + xlimit[1]), 0.5 * (ylimit[0] + ylimit[1]), 
#         r'$\sigma=6.0$', fontsize=fontsize)
# ax.set_xlim(xlimit)
# ax.set_ylim(ylimit)
# ax.set_xticks([])
# ax.set_yticks([])
# ax.axis('off')

# ax = fig.add_subplot(spec[1, 0])
# ax.text(0.5 * (xlimit[0] + xlimit[1]), 0.5 * (ylimit[0] + ylimit[1]), 
#         r'$\sigma=8.0$', fontsize=fontsize)
# ax.set_xlim(xlimit)
# ax.set_ylim(ylimit)
# ax.set_xticks([])
# ax.set_yticks([])
# ax.axis('off')

# ax = fig.add_subplot(spec[2, 0])
# ax.text(0.5 * (xlimit[0] + xlimit[1]), 0.5 * (ylimit[0] + ylimit[1]), 
#         r'$\sigma=10.0$', fontsize=fontsize)
# ax.set_xlim(xlimit)
# ax.set_ylim(ylimit)
# ax.set_xticks([])
# ax.set_yticks([])
# ax.axis('off')

# ax = fig.add_subplot(spec[3, 0])
# ax.text(0.5 * (xlimit[0] + xlimit[1]), 0.5 * (ylimit[0] + ylimit[1]), 
#         r'$\sigma=12.0$', fontsize=fontsize)
# ax.set_xlim(xlimit)
# ax.set_ylim(ylimit)
# ax.set_xticks([])
# ax.set_yticks([])
# ax.axis('off')

# ---------------------------------------------------------------------------------
# plot of original data 
for i in range(nrows): 
    
    ax = fig.add_subplot(spec[i, 0])
    true_data = np.load('geyser.npy').astype(np.float64)
    df = deepcopy(true_data[:, 0]).reshape(-1, 1)
    pddf = pd.DataFrame({'vals': df.flatten(), 
                         'cate': [False if df[i] >= 105. else True for i in range(df.shape[0])]})
    bw = bw_list[i]
    file_name = f'original_denvals_scorematching_bw={bw}_all.npy'
    denvals = np.load(f'low_density_region/{basisfunction_name}_basis_function/' + file_name)

    ax.plot(x0.flatten(), denvals.flatten(), color = 'tab:blue', linewidth = linewidth)
    # seaborn.rugplot(data = pddf, x = 'vals', axis = 'x', ax = ax, hue = 'cate', clip_on = False)
    seaborn.rugplot(pddf['vals'], axis = 'x', ax = ax)
    seaborn.rugplot(df[df >= 105.], axis = 'x', ax = ax, color = 'red')
    
    ax.hist(df.flatten(),
            color='tab:blue',
            bins='fd',
            range=xlimit,
            density=True,
            alpha=0.4)
    ax.set_ylabel('$\sigma$={bw}\ndensity'.format(bw=bw), fontsize = fontsize_label)
    ax.set_xlim(xlimit)
    ax.set_ylim(ylimit)
    # ax.ticklabel_format(axis = 'y', style = 'sci', scilimits = scilimits)
    ax.tick_params(axis = 'both', labelsize = fontsize_tick)
    if i != 3: 
        ax.set_xticks([])
    if i == 3: 
        ax.tick_params(axis = 'both', labelsize = fontsize_tick)
        ax.set_xlabel(var_name, fontsize = fontsize_label)

    info = r"Original"
    
    ax.text(0.012, 0.988,
            info,
            fontsize = fontsize_info,
            multialignment = 'left',
            horizontalalignment = 'left',
            verticalalignment = 'top',
            transform = ax.transAxes,
            bbox = {'facecolor': 'none',
                    'boxstyle': 'Round, pad=0.2'})

# ------------------------------------------------------------------------------------
# remove 108 
for i in range(nrows): 
    
    ax = fig.add_subplot(spec[i, 1])
    true_data = np.load('geyser.npy').astype(np.float64)
    df = deepcopy(true_data[:, 0]).reshape(-1, 1)
    df = df[df != 108.]
    pddf = pd.DataFrame({'vals': df.flatten(), 
                         'cate': [False if df[i] >= 100. else True for i in range(df.shape[0])]})
    bw = bw_list[i]
    file_name = f'remove108_denvals_scorematching_bw={bw}_all.npy'
    denvals = np.load(f'low_density_region/{basisfunction_name}_basis_function/' + file_name)

    ax.plot(x0.flatten(), denvals.flatten(), color = 'tab:blue', linewidth = linewidth)
    # seaborn.rugplot(data = pddf, x = 'vals', axis = 'x', ax = ax, hue = 'cate', clip_on = False)
    seaborn.rugplot(pddf['vals'], axis = 'x', ax = ax)
    seaborn.rugplot(df[df >= 100.], axis = 'x', ax = ax, color = 'red')
    
    ax.hist(df.flatten(),
            color='tab:blue',
            bins='fd',
            range=xlimit,
            density=True,
            alpha=0.4)
    ax.set_xlim(xlimit)
    ax.set_ylim(ylimit)
    if i != 3: 
        ax.set_xticks([])
    
    if i == 3: 
        ax.tick_params(axis = 'both', labelsize = fontsize_tick)
        ax.set_xlabel(var_name, fontsize = fontsize_label)
    ax.set_yticks([])
    
    info = r"Remove 108"
    
    ax.text(0.012, 0.988,
            info,
            fontsize = fontsize_info,
            multialignment = 'left',
            horizontalalignment = 'left',
            verticalalignment = 'top',
            transform = ax.transAxes,
            bbox = {'facecolor': 'none',
                    'boxstyle': 'Round, pad=0.2'})

# ------------------------------------------------------------------------------------
# Add 106
for i in range(nrows): 
    
    ax = fig.add_subplot(spec[i, 2])
    true_data = np.load('geyser.npy').astype(np.float64)
    df = deepcopy(true_data[:, 0]).reshape(-1, 1)
    df = np.vstack([df, np.array([[106.]])])
    pddf = pd.DataFrame({'vals': df.flatten(), 
                         'cate': [False if df[i] >= 100. else True for i in range(df.shape[0])]})
    bw = bw_list[i]
    file_name = f'add106_denvals_scorematching_bw={bw}_all.npy'
    denvals = np.load(f'low_density_region/{basisfunction_name}_basis_function/' + file_name)

    ax.plot(x0.flatten(), denvals.flatten(), color = 'tab:blue', linewidth = linewidth)
    # seaborn.rugplot(data = pddf, x = 'vals', axis = 'x', ax = ax, hue = 'cate', clip_on = False)
    seaborn.rugplot(pddf['vals'], axis = 'x', ax = ax)
    seaborn.rugplot(df[df >= 100.], axis = 'x', ax = ax, color = 'red')
    
    ax.hist(df.flatten(),
            color='tab:blue',
            bins='fd',
            range=xlimit,
            density=True,
            alpha=0.4)
    ax.set_xlim(xlimit)
    ax.set_ylim(ylimit)
    # ax.axvline(108., 0, 1, ls = '--', color = 'tab:purple', alpha = 0.5)
    # ax.ticklabel_format(axis = 'y', style = 'sci', scilimits = scilimits)
    ax.tick_params(axis = 'both', labelsize = fontsize_tick)
    if i != 3: 
        ax.set_xticks([])
    
    if i == 3: 
        ax.set_xlabel(var_name, fontsize = fontsize_label)
        ax.tick_params(axis = 'both', labelsize = fontsize_tick)
    ax.set_yticks([])
    
    info = r"Add 106"
    
    ax.text(0.012, 0.988,
            info,
            fontsize = fontsize_info,
            multialignment = 'left',
            horizontalalignment = 'left',
            verticalalignment = 'top',
            transform = ax.transAxes,
            bbox = {'facecolor': 'none',
                    'boxstyle': 'Round, pad=0.2'})

# ------------------------------------------------------------------------------------
# Add 107
for i in range(nrows): 
    
    ax = fig.add_subplot(spec[i, 3])
    true_data = np.load('geyser.npy').astype(np.float64)
    df = deepcopy(true_data[:, 0]).reshape(-1, 1)
    df = np.vstack([df, np.array([[107.]])])
    pddf = pd.DataFrame({'vals': df.flatten(), 
                         'cate': [False if df[i] >= 100. else True for i in range(df.shape[0])]})
    bw = bw_list[i]
    file_name = f'add107_denvals_scorematching_bw={bw}_all.npy'
    denvals = np.load(f'low_density_region/{basisfunction_name}_basis_function/' + file_name)

    ax.plot(x0.flatten(), denvals.flatten(), color = 'tab:blue', linewidth = linewidth)
    # seaborn.rugplot(data = pddf, x = 'vals', axis = 'x', ax = ax, hue = 'cate', clip_on = False)
    seaborn.rugplot(pddf['vals'], axis = 'x', ax = ax)
    seaborn.rugplot(df[df >= 100.], axis = 'x', ax = ax, color = 'red')
    
    ax.hist(df.flatten(),
            color='tab:blue',
            bins='fd',
            range=xlimit,
            density=True,
            alpha=0.4)
    ax.set_xlim(xlimit)
    ax.set_ylim(ylimit)
    if i != 3: 
        ax.set_xticks([])
    
    if i == 3: 
        ax.set_xlabel(var_name, fontsize = fontsize_label)
        ax.tick_params(axis = 'both', labelsize = fontsize_tick)
    ax.set_yticks([])
    
    info = r"Add 107"
    
    ax.text(0.012, 0.988,
            info,
            fontsize = fontsize_info,
            multialignment = 'left',
            horizontalalignment = 'left',
            verticalalignment = 'top',
            transform = ax.transAxes,
            bbox = {'facecolor': 'none',
                    'boxstyle': 'Round, pad=0.2'})

# # ------------------------------------------------------------------------------------
# # Add 106 and 107
# for i in range(nrows): 
    
#     ax = fig.add_subplot(spec[i, 5])
#     true_data = np.load('geyser.npy').astype(np.float64)
#     df = deepcopy(true_data[:, 0]).reshape(-1, 1)
#     df = np.vstack([df, np.array([[107.], [106.]])])
#     pddf = pd.DataFrame({'vals': df.flatten(), 
#                          'cate': [False if df[i] >= 100. else True for i in range(df.shape[0])]})
#     bw = bw_list[i]
#     file_name = f'add106107_denvals_scorematching_bw={bw}_all.npy'
#     denvals = np.load(f'low_density_region/{basisfunction_name}_basis_function/' + file_name)

#     ax.plot(x0.flatten(), denvals.flatten(), color = 'tab:blue', linewidth = linewidth)
#     # seaborn.rugplot(data = pddf, x = 'vals', axis = 'x', ax = ax, hue = 'cate', clip_on = False)
#     seaborn.rugplot(pddf['vals'], axis = 'x', ax = ax)
#     seaborn.rugplot(df[df >= 100.], axis = 'x', ax = ax, color = 'red')
    
#     ax.hist(df.flatten(),
#             color='tab:blue',
#             bins='fd',
#             range=xlimit,
#             density=True,
#             alpha=0.4)
#     ax.set_xlim(xlimit)
#     ax.set_ylim(ylimit)
#     # ax.axvline(108., 0, 1, ls = '--', color = 'tab:purple', alpha = 0.5)
#     # ax.tick_params(axis = 'both', labelsize = fontsize)
#     # ax.ticklabel_format(axis = 'y', style = 'sci', scilimits = scilimits)
#     ax.tick_params(axis = 'both', labelsize = fontsize)
#     if i != 3: 
#         ax.set_xticks([])
    
#     if i == 3: 
#         ax.set_xlabel(var_name, fontsize = fontsize)
#     ax.set_yticks([])
    
#     info = r"Add 106 and 107"
    
#     ax.text(0.012, 0.988,
#             info,
#             fontsize = fontsize_info,
#             multialignment = 'left',
#             horizontalalignment = 'left',
#             verticalalignment = 'top',
#             transform = ax.transAxes,
#             bbox = {'facecolor': 'none',
#                     'boxstyle': 'Round, pad=0.2'})

# ------------------------------------------------------------------------------------
# Add 106 and 107
for i in range(nrows): 
    
    ax = fig.add_subplot(spec[i, 4])
    true_data = np.load('geyser.npy').astype(np.float64)
    df = deepcopy(true_data[:, 0]).reshape(-1, 1)
    df = np.vstack([df, np.array([[100.], [102.], [104.], [106.]])])
    pddf = pd.DataFrame({'vals': df.flatten(), 
                         'cate': [False if df[i] >= 100. else True for i in range(df.shape[0])]})
    bw = bw_list[i]
    file_name = f'add100102104106_denvals_scorematching_bw={bw}_all.npy'
    denvals = np.load(f'low_density_region/{basisfunction_name}_basis_function/' + file_name)

    ax.plot(x0.flatten(), denvals.flatten(), color = 'tab:blue', linewidth = linewidth)
    # seaborn.rugplot(data = pddf, x = 'vals', axis = 'x', ax = ax, hue = 'cate', clip_on = False)
    seaborn.rugplot(pddf['vals'], axis = 'x', ax = ax)
    seaborn.rugplot(df[df >= 100.], axis = 'x', ax = ax, color = 'red')
    
    ax.hist(df.flatten(),
            color='tab:blue',
            bins='fd',
            range=xlimit,
            density=True,
            alpha=0.4)
    ax.set_xlim(xlimit)
    ax.set_ylim(ylimit)
    ax.tick_params(axis = 'both', labelsize = fontsize_tick)
    if i != 3: 
        ax.set_xticks([])
    
    if i == 3: 
        ax.set_xlabel(var_name, fontsize = fontsize_label)
        ax.tick_params(axis = 'both', labelsize = fontsize_tick)
    ax.set_yticks([])
    
    info = r"Add 100, 102, ..., 106"
    
    ax.text(0.012, 0.988,
            info,
            fontsize = fontsize_info,
            multialignment = 'left',
            horizontalalignment = 'left',
            verticalalignment = 'top',
            transform = ax.transAxes,
            bbox = {'facecolor': 'none',
                    'boxstyle': 'Round, pad=0.2'})
    
plt.tight_layout()
# plt.savefig('low_density_region.pdf')

# %%
fig = plt.figure(constrained_layout=False)

plot_pts_cnt = 4000
xlimit = (21., 124.)
ylimit = (-0.005, 0.0701)

x0 = np.linspace(xlimit[0], xlimit[1], plot_pts_cnt).reshape(-1, 1)

basisfunction_name = 'Gaussian'
var_name = 'waiting'
fig.set_figheight(30) # 40 
fig.set_figwidth(80) # 65
ncols = 8
nrows = 3
fontsize_label = 40
fontsize_info = 40
fontsize_tick = 25
linewidth = 2.0

bw_list = [6.0, 8.0, 10.0]

widths = [1, 1, 1, 1, 1]
heights = [1, 1, 1, 1]
spec = fig.add_gridspec(ncols = ncols, 
                        nrows = nrows, 
                        width_ratios = widths,
                        height_ratios = heights)

# spec = gridspec.GridSpec(ncols=ncols, nrows=nrows, figure=fig)

# # ---------------------------------------------------------------------------------------------
# ax = fig.add_subplot(spec[0, 0])
# ax.text(0.5 * (xlimit[0] + xlimit[1]), 0.5 * (ylimit[0] + ylimit[1]), 
#         r'$\sigma=6.0$', fontsize=fontsize)
# ax.set_xlim(xlimit)
# ax.set_ylim(ylimit)
# ax.set_xticks([])
# ax.set_yticks([])
# ax.axis('off')

# ax = fig.add_subplot(spec[1, 0])
# ax.text(0.5 * (xlimit[0] + xlimit[1]), 0.5 * (ylimit[0] + ylimit[1]), 
#         r'$\sigma=8.0$', fontsize=fontsize)
# ax.set_xlim(xlimit)
# ax.set_ylim(ylimit)
# ax.set_xticks([])
# ax.set_yticks([])
# ax.axis('off')

# ax = fig.add_subplot(spec[2, 0])
# ax.text(0.5 * (xlimit[0] + xlimit[1]), 0.5 * (ylimit[0] + ylimit[1]), 
#         r'$\sigma=10.0$', fontsize=fontsize)
# ax.set_xlim(xlimit)
# ax.set_ylim(ylimit)
# ax.set_xticks([])
# ax.set_yticks([])
# ax.axis('off')

# ax = fig.add_subplot(spec[3, 0])
# ax.text(0.5 * (xlimit[0] + xlimit[1]), 0.5 * (ylimit[0] + ylimit[1]), 
#         r'$\sigma=12.0$', fontsize=fontsize)
# ax.set_xlim(xlimit)
# ax.set_ylim(ylimit)
# ax.set_xticks([])
# ax.set_yticks([])
# ax.axis('off')

# ---------------------------------------------------------------------------------
# plot of original data 
for i in range(nrows): 
    
    ax = fig.add_subplot(spec[i, 0])
    true_data = np.load('geyser.npy').astype(np.float64)
    df = deepcopy(true_data[:, 0]).reshape(-1, 1)
    pddf = pd.DataFrame({'vals': df.flatten(), 
                         'cate': [False if df[i] >= 105. else True for i in range(df.shape[0])]})
    bw = bw_list[i]
    file_name = f'original_denvals_scorematching_bw={bw}_all.npy'
    denvals = np.load(f'low_density_region/{basisfunction_name}_basis_function/' + file_name)

    ax.plot(x0.flatten(), denvals.flatten(), color = 'tab:blue', linewidth = linewidth)
    # seaborn.rugplot(data = pddf, x = 'vals', axis = 'x', ax = ax, hue = 'cate', clip_on = False)
    seaborn.rugplot(pddf['vals'], axis = 'x', ax = ax)
    seaborn.rugplot(df[df >= 105.], axis = 'x', ax = ax, color = 'red')
    
    ax.hist(df.flatten(),
            color='tab:blue',
            bins='fd',
            range=xlimit,
            density=True,
            alpha=0.4)
    ax.set_ylabel('$\sigma$={bw}\ndensity'.format(bw=bw), fontsize = fontsize_label)
    ax.set_xlim(xlimit)
    ax.set_ylim(ylimit)
    # ax.ticklabel_format(axis = 'y', style = 'sci', scilimits = scilimits)
    ax.tick_params(axis = 'both', labelsize = fontsize_tick)
    if i != 3: 
        ax.set_xticks([])
    if i == 3: 
        ax.tick_params(axis = 'both', labelsize = fontsize_tick)
        ax.set_xlabel(var_name, fontsize = fontsize_label)

    info = r"Original"
    
    ax.text(0.012, 0.988,
            info,
            fontsize = fontsize_info,
            multialignment = 'left',
            horizontalalignment = 'left',
            verticalalignment = 'top',
            transform = ax.transAxes,
            bbox = {'facecolor': 'none',
                    'boxstyle': 'Round, pad=0.2'})

# ------------------------------------------------------------------------------------
# remove 108 
for i in range(nrows): 
    
    ax = fig.add_subplot(spec[i, 1])
    true_data = np.load('geyser.npy').astype(np.float64)
    df = deepcopy(true_data[:, 0]).reshape(-1, 1)
    df = df[df != 108.]
    pddf = pd.DataFrame({'vals': df.flatten(), 
                         'cate': [False if df[i] >= 100. else True for i in range(df.shape[0])]})
    bw = bw_list[i]
    file_name = f'remove108_denvals_scorematching_bw={bw}_all.npy'
    denvals = np.load(f'low_density_region/{basisfunction_name}_basis_function/' + file_name)

    ax.plot(x0.flatten(), denvals.flatten(), color = 'tab:blue', linewidth = linewidth)
    # seaborn.rugplot(data = pddf, x = 'vals', axis = 'x', ax = ax, hue = 'cate', clip_on = False)
    seaborn.rugplot(pddf['vals'], axis = 'x', ax = ax)
    seaborn.rugplot(df[df >= 100.], axis = 'x', ax = ax, color = 'red')
    
    ax.hist(df.flatten(),
            color='tab:blue',
            bins='fd',
            range=xlimit,
            density=True,
            alpha=0.4)
    ax.set_xlim(xlimit)
    ax.set_ylim(ylimit)
    if i != 3: 
        ax.set_xticks([])
    
    if i == 3: 
        ax.tick_params(axis = 'both', labelsize = fontsize_tick)
        ax.set_xlabel(var_name, fontsize = fontsize_label)
    ax.set_yticks([])
    
    info = r"Remove 108"
    
    ax.text(0.012, 0.988,
            info,
            fontsize = fontsize_info,
            multialignment = 'left',
            horizontalalignment = 'left',
            verticalalignment = 'top',
            transform = ax.transAxes,
            bbox = {'facecolor': 'none',
                    'boxstyle': 'Round, pad=0.2'})

# ------------------------------------------------------------------------------------
# Add 106
for i in range(nrows): 
    
    ax = fig.add_subplot(spec[i, 2])
    true_data = np.load('geyser.npy').astype(np.float64)
    df = deepcopy(true_data[:, 0]).reshape(-1, 1)
    df = np.vstack([df, np.array([[106.]])])
    pddf = pd.DataFrame({'vals': df.flatten(), 
                         'cate': [False if df[i] >= 100. else True for i in range(df.shape[0])]})
    bw = bw_list[i]
    file_name = f'add106_denvals_scorematching_bw={bw}_all.npy'
    denvals = np.load(f'low_density_region/{basisfunction_name}_basis_function/' + file_name)

    ax.plot(x0.flatten(), denvals.flatten(), color = 'tab:blue', linewidth = linewidth)
    # seaborn.rugplot(data = pddf, x = 'vals', axis = 'x', ax = ax, hue = 'cate', clip_on = False)
    seaborn.rugplot(pddf['vals'], axis = 'x', ax = ax)
    seaborn.rugplot(df[df >= 100.], axis = 'x', ax = ax, color = 'red')
    
    ax.hist(df.flatten(),
            color='tab:blue',
            bins='fd',
            range=xlimit,
            density=True,
            alpha=0.4)
    ax.set_xlim(xlimit)
    ax.set_ylim(ylimit)
    # ax.axvline(108., 0, 1, ls = '--', color = 'tab:purple', alpha = 0.5)
    # ax.ticklabel_format(axis = 'y', style = 'sci', scilimits = scilimits)
    ax.tick_params(axis = 'both', labelsize = fontsize_tick)
    if i != 3: 
        ax.set_xticks([])
    
    if i == 3: 
        ax.set_xlabel(var_name, fontsize = fontsize_label)
        ax.tick_params(axis = 'both', labelsize = fontsize_tick)
    ax.set_yticks([])
    
    info = r"Add 106"
    
    ax.text(0.012, 0.988,
            info,
            fontsize = fontsize_info,
            multialignment = 'left',
            horizontalalignment = 'left',
            verticalalignment = 'top',
            transform = ax.transAxes,
            bbox = {'facecolor': 'none',
                    'boxstyle': 'Round, pad=0.2'})

# ------------------------------------------------------------------------------------
# Add 107
for i in range(nrows): 
    
    ax = fig.add_subplot(spec[i, 3])
    true_data = np.load('geyser.npy').astype(np.float64)
    df = deepcopy(true_data[:, 0]).reshape(-1, 1)
    df = np.vstack([df, np.array([[107.]])])
    pddf = pd.DataFrame({'vals': df.flatten(), 
                         'cate': [False if df[i] >= 100. else True for i in range(df.shape[0])]})
    bw = bw_list[i]
    file_name = f'add107_denvals_scorematching_bw={bw}_all.npy'
    denvals = np.load(f'low_density_region/{basisfunction_name}_basis_function/' + file_name)

    ax.plot(x0.flatten(), denvals.flatten(), color = 'tab:blue', linewidth = linewidth)
    # seaborn.rugplot(data = pddf, x = 'vals', axis = 'x', ax = ax, hue = 'cate', clip_on = False)
    seaborn.rugplot(pddf['vals'], axis = 'x', ax = ax)
    seaborn.rugplot(df[df >= 100.], axis = 'x', ax = ax, color = 'red')
    
    ax.hist(df.flatten(),
            color='tab:blue',
            bins='fd',
            range=xlimit,
            density=True,
            alpha=0.4)
    ax.set_xlim(xlimit)
    ax.set_ylim(ylimit)
    if i != 3: 
        ax.set_xticks([])
    
    if i == 3: 
        ax.set_xlabel(var_name, fontsize = fontsize_label)
        ax.tick_params(axis = 'both', labelsize = fontsize_tick)
    ax.set_yticks([])
    
    info = r"Add 107"
    
    ax.text(0.012, 0.988,
            info,
            fontsize = fontsize_info,
            multialignment = 'left',
            horizontalalignment = 'left',
            verticalalignment = 'top',
            transform = ax.transAxes,
            bbox = {'facecolor': 'none',
                    'boxstyle': 'Round, pad=0.2'})

# # ------------------------------------------------------------------------------------
# # Add 106 and 107
# for i in range(nrows): 
    
#     ax = fig.add_subplot(spec[i, 5])
#     true_data = np.load('geyser.npy').astype(np.float64)
#     df = deepcopy(true_data[:, 0]).reshape(-1, 1)
#     df = np.vstack([df, np.array([[107.], [106.]])])
#     pddf = pd.DataFrame({'vals': df.flatten(), 
#                          'cate': [False if df[i] >= 100. else True for i in range(df.shape[0])]})
#     bw = bw_list[i]
#     file_name = f'add106107_denvals_scorematching_bw={bw}_all.npy'
#     denvals = np.load(f'low_density_region/{basisfunction_name}_basis_function/' + file_name)

#     ax.plot(x0.flatten(), denvals.flatten(), color = 'tab:blue', linewidth = linewidth)
#     # seaborn.rugplot(data = pddf, x = 'vals', axis = 'x', ax = ax, hue = 'cate', clip_on = False)
#     seaborn.rugplot(pddf['vals'], axis = 'x', ax = ax)
#     seaborn.rugplot(df[df >= 100.], axis = 'x', ax = ax, color = 'red')
    
#     ax.hist(df.flatten(),
#             color='tab:blue',
#             bins='fd',
#             range=xlimit,
#             density=True,
#             alpha=0.4)
#     ax.set_xlim(xlimit)
#     ax.set_ylim(ylimit)
#     # ax.axvline(108., 0, 1, ls = '--', color = 'tab:purple', alpha = 0.5)
#     # ax.tick_params(axis = 'both', labelsize = fontsize)
#     # ax.ticklabel_format(axis = 'y', style = 'sci', scilimits = scilimits)
#     ax.tick_params(axis = 'both', labelsize = fontsize)
#     if i != 3: 
#         ax.set_xticks([])
    
#     if i == 3: 
#         ax.set_xlabel(var_name, fontsize = fontsize)
#     ax.set_yticks([])
    
#     info = r"Add 106 and 107"
    
#     ax.text(0.012, 0.988,
#             info,
#             fontsize = fontsize_info,
#             multialignment = 'left',
#             horizontalalignment = 'left',
#             verticalalignment = 'top',
#             transform = ax.transAxes,
#             bbox = {'facecolor': 'none',
#                     'boxstyle': 'Round, pad=0.2'})

# ------------------------------------------------------------------------------------
# Add 106 and 107
for i in range(nrows): 
    
    ax = fig.add_subplot(spec[i, 4])
    true_data = np.load('geyser.npy').astype(np.float64)
    df = deepcopy(true_data[:, 0]).reshape(-1, 1)
    df = np.vstack([df, np.array([[100.], [102.], [104.], [106.]])])
    pddf = pd.DataFrame({'vals': df.flatten(), 
                         'cate': [False if df[i] >= 100. else True for i in range(df.shape[0])]})
    bw = bw_list[i]
    file_name = f'add100102104106_denvals_scorematching_bw={bw}_all.npy'
    denvals = np.load(f'low_density_region/{basisfunction_name}_basis_function/' + file_name)

    ax.plot(x0.flatten(), denvals.flatten(), color = 'tab:blue', linewidth = linewidth)
    # seaborn.rugplot(data = pddf, x = 'vals', axis = 'x', ax = ax, hue = 'cate', clip_on = False)
    seaborn.rugplot(pddf['vals'], axis = 'x', ax = ax)
    seaborn.rugplot(df[df >= 100.], axis = 'x', ax = ax, color = 'red')
    
    ax.hist(df.flatten(),
            color='tab:blue',
            bins='fd',
            range=xlimit,
            density=True,
            alpha=0.4)
    ax.set_xlim(xlimit)
    ax.set_ylim(ylimit)
    ax.tick_params(axis = 'both', labelsize = fontsize_tick)
    if i != 3: 
        ax.set_xticks([])
    
    if i == 3: 
        ax.set_xlabel(var_name, fontsize = fontsize_label)
        ax.tick_params(axis = 'both', labelsize = fontsize_tick)
    ax.set_yticks([])
    
    info = r"Add 100, 102, ..., 106"
    
    ax.text(0.012, 0.988,
            info,
            fontsize = fontsize_info,
            multialignment = 'left',
            horizontalalignment = 'left',
            verticalalignment = 'top',
            transform = ax.transAxes,
            bbox = {'facecolor': 'none',
                    'boxstyle': 'Round, pad=0.2'})
    
plt.tight_layout()
# plt.savefig('low_density_region.pdf')

# %%
os.getcwd()
